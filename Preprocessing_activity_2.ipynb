# %%
import pandas as pd

# %%
data = pd.read_csv("train_dataset.csv")

# %%
data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
data.shape
# Out:
# (8523, 12)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
data.describe().T
# Out:
#                             count         mean          std       min  \
# Item_Weight                7060.0    12.857645     4.643456     4.555
# Item_Visibility            8523.0     0.066132     0.051598     0.000
# Item_MRP                   8523.0   140.992782    62.275067    31.290
# Outlet_Establishment_Year  8523.0  1997.831867     8.371760  1985.000
# Item_Outlet_Sales          8523.0  2181.288914  1706.499616    33.290
#
#                                    25%          50%          75%           max
# Item_Weight                   8.773750    12.600000    16.850000     21.350000
# Item_Visibility               0.026989     0.053931     0.094585      0.328391
# Item_MRP                     93.826500   143.012800   185.643700    266.888400
# Outlet_Establishment_Year  1987.000000  1999.000000  2004.000000   2009.000000
# Item_Outlet_Sales           834.247400  1794.331000  3101.296400  13086.964800

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
data.notna().sum()
# Out:
# Item_Identifier              8523
# Item_Weight                  7060
# Item_Fat_Content             8523
# Item_Visibility              8523
# Item_Type                    8523
# Item_MRP                     8523
# Outlet_Identifier            8523
# Outlet_Establishment_Year    8523
# Outlet_Size                  6113
# Outlet_Location_Type         8523
# Outlet_Type                  8523
# Item_Outlet_Sales            8523
# dtype: int64

# %%
import numpy as np

# %%
#Script to find the outliers
for col_name in data.select_dtypes(include=np.number).columns[:-1]:
    print(col_name)
    q1 = data[col_name].quantile(0.25)
    q3 = data[col_name].quantile(0.75)
    iqr = q3 - q1
    
    low = q1-1.5*iqr
    high = q3+1.5*iqr
    print("Outliers = ",data.loc[(data[col_name] < low) | (data[col_name] > high), col_name])
# Out:
# Item_Weight
# Outliers =  Series([], Name: Item_Weight, dtype: float64)
# Item_Visibility
# Outliers =  49      0.255395
# 83      0.293418
# 108     0.278974
# 174     0.291865
# 334     0.204700
#           ...
# 8292    0.209163
# 8345    0.266397
# 8371    0.214125
# 8432    0.227261
# 8509    0.214306
# Name: Item_Visibility, Length: 144, dtype: float64
# Item_MRP
# Outliers =  Series([], Name: Item_MRP, dtype: float64)
# Outlet_Establishment_Year
# Outliers =  Series([], Name: Outlet_Establishment_Year, dtype: int64)

# %%
data
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
data.Item_Identifier.unique()
# Out:
# array(['FDA15', 'DRC01', 'FDN15', ..., 'NCF55', 'NCW30', 'NCW05'],
#       dtype=object)

# %%
data.Item_Weight.unique()
# Out:
# array([ 9.3  ,  5.92 , 17.5  , 19.2  ,  8.93 , 10.395, 13.65 ,    nan,
#        16.2  , 11.8  , 18.5  , 15.1  , 17.6  , 16.35 ,  9.   , 13.35 ,
#        18.85 , 14.6  , 13.85 , 13.   ,  7.645, 11.65 ,  5.925, 19.25 ,
#        18.6  , 18.7  , 17.85 , 10.   ,  8.85 ,  9.8  , 13.6  , 21.35 ,
#        12.15 ,  6.42 , 19.6  , 15.85 ,  7.39 , 10.195,  9.895, 10.895,
#         7.905,  9.195,  8.365,  7.97 , 17.7  , 19.35 ,  8.645, 15.6  ,
#        18.25 ,  7.855,  7.825,  8.39 , 12.85 , 19.   ,  5.905,  7.76 ,
#        16.75 , 15.5  ,  6.055,  6.305, 20.85 , 20.75 ,  8.895, 19.7  ,
#         8.75 , 13.3  ,  8.31 , 19.75 , 17.1  , 10.5  ,  6.635, 14.15 ,
#         8.89 ,  9.1  ,  7.5  , 16.85 ,  7.485, 11.6  , 12.65 , 20.25 ,
#         8.6  , 12.6  ,  8.88 , 20.5  , 13.5  ,  7.235,  6.92 ,  8.02 ,
#        12.8  , 16.6  , 14.   , 16.   , 21.25 ,  7.365, 18.35 ,  5.465,
#         7.27 ,  6.155, 19.5  , 15.2  , 14.5  , 13.1  , 12.3  , 11.1  ,
# ...

# %%
data.Item_Weight.isna().sum()
# Out:
# 1463

# %%
b=data[["Item_Weight","Item_Type"]]

# %%
b[b["Item_Weight"].isna()].drop_duplicates()
# Out:
#      Item_Weight              Item_Type
# 7            NaN            Snack Foods
# 18           NaN            Hard Drinks
# 21           NaN           Baking Goods
# 29           NaN                 Canned
# 36           NaN  Fruits and Vegetables
# 49           NaN                  Dairy
# 63           NaN           Frozen Foods
# 83           NaN              Household
# 87           NaN              Breakfast
# 108          NaN            Soft Drinks
# 112          NaN                   Meat
# 132          NaN     Health and Hygiene
# 136          NaN          Starchy Foods
# 225          NaN                 Others
# 231          NaN                Seafood
# 417          NaN                 Breads

# %%
b.groupby('Item_Type').Item_Weight.median()
# Out:
# Item_Type
# Baking Goods             11.650
# Breads                   10.600
# Breakfast                10.695
# Canned                   12.150
# Dairy                    13.350
# Frozen Foods             12.850
# Fruits and Vegetables    13.100
# Hard Drinks              10.100
# Health and Hygiene       12.150
# Household                13.150
# Meat                     12.350
# Others                   14.500
# Seafood                  11.650
# Snack Foods              13.150
# Soft Drinks              11.800
# Starchy Foods            13.175
# Name: Item_Weight, dtype: float64

# %%
data[data["Item_Weight"].isna()]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 7              FDP10          NaN          Low Fat         0.127470
# 18             DRI11          NaN          Low Fat         0.034238
# 21             FDW12          NaN          Regular         0.035400
# 23             FDC37          NaN          Low Fat         0.057557
# 29             FDC14          NaN          Regular         0.072222
# ...              ...          ...              ...              ...
# 8485           DRK37          NaN          Low Fat         0.043792
# 8487           DRG13          NaN          Low Fat         0.037006
# 8488           NCN14          NaN          Low Fat         0.091473
# 8490           FDU44          NaN          Regular         0.102296
# 8504           NCN18          NaN          Low Fat         0.124111
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 7               Snack Foods  107.7622            OUT027
# ...

# %%
data.groupby('Item_Type').Item_Weight.median()
# Out:
# Item_Type
# Baking Goods             11.650
# Breads                   10.600
# Breakfast                10.695
# Canned                   12.150
# Dairy                    13.350
# Frozen Foods             12.850
# Fruits and Vegetables    13.100
# Hard Drinks              10.100
# Health and Hygiene       12.150
# Household                13.150
# Meat                     12.350
# Others                   14.500
# Seafood                  11.650
# Snack Foods              13.150
# Soft Drinks              11.800
# Starchy Foods            13.175
# Name: Item_Weight, dtype: float64

# %%
#data["Item_Weight"].fillna(data.groupby('Item_Type').Item_Weight.median(), inplace = True)

data.loc[data['Item_Type'].eq('Baking Goods') & data['Item_Weight'].isnull(), 'Item_Weight'] = 11.650
data.loc[data['Item_Type'].eq('Breads') & data['Item_Weight'].isnull(), 'Item_Weight'] = 10.600
data.loc[data['Item_Type'].eq('Breakfast') & data['Item_Weight'].isnull(), 'Item_Weight'] = 10.695
data.loc[data['Item_Type'].eq('Canned') & data['Item_Weight'].isnull(), 'Item_Weight'] = 12.150
data.loc[data['Item_Type'].eq('Dairy') & data['Item_Weight'].isnull(), 'Item_Weight'] = 13.350
data.loc[data['Item_Type'].eq('Frozen Foods') & data['Item_Weight'].isnull(), 'Item_Weight'] = 12.850
data.loc[data['Item_Type'].eq('Fruits and Vegetables') & data['Item_Weight'].isnull(), 'Item_Weight'] =13.100
data.loc[data['Item_Type'].eq('Hard Drinks') & data['Item_Weight'].isnull(), 'Item_Weight'] = 10.100
data.loc[data['Item_Type'].eq('Health and Hygiene') & data['Item_Weight'].isnull(), 'Item_Weight'] = 12.150
data.loc[data['Item_Type'].eq('Household') & data['Item_Weight'].isnull(), 'Item_Weight'] = 13.150
data.loc[data['Item_Type'].eq('Meat') & data['Item_Weight'].isnull(), 'Item_Weight'] = 12.350
data.loc[data['Item_Type'].eq('Others') & data['Item_Weight'].isnull(), 'Item_Weight'] = 14.500
data.loc[data['Item_Type'].eq('Seafood') & data['Item_Weight'].isnull(), 'Item_Weight'] = 11.650
data.loc[data['Item_Type'].eq('Snack Foods') & data['Item_Weight'].isnull(), 'Item_Weight'] = 13.150
data.loc[data['Item_Type'].eq('Soft Drinks') & data['Item_Weight'].isnull(), 'Item_Weight'] = 11.800
data.loc[data['Item_Type'].eq('Starchy Foods') & data['Item_Weight'].isnull(), 'Item_Weight'] = 13.175

# %%
data["Item_Weight"].isna().sum()
# Out:
# 0

# %%
data.Item_Fat_Content.unique()
# Out:
# array(['Low Fat', 'Regular', 'low fat', 'LF', 'reg'], dtype=object)

# %%
data.Item_Visibility.unique()
# Out:
# array([0.0160473 , 0.01927822, 0.01676007, ..., 0.03518627, 0.14522065,
#        0.04487828])

# %%
data.Item_Type.unique()
# Out:
# array(['Dairy', 'Soft Drinks', 'Meat', 'Fruits and Vegetables',
#        'Household', 'Baking Goods', 'Snack Foods', 'Frozen Foods',
#        'Breakfast', 'Health and Hygiene', 'Hard Drinks', 'Canned',
#        'Breads', 'Starchy Foods', 'Others', 'Seafood'], dtype=object)

# %%
data.Item_MRP.unique()
# Out:
# array([249.8092,  48.2692, 141.618 , ...,  57.5904, 214.5218,  75.467 ])

# %%
data.Outlet_Identifier.unique()
# Out:
# array(['OUT049', 'OUT018', 'OUT010', 'OUT013', 'OUT027', 'OUT045',
#        'OUT017', 'OUT046', 'OUT035', 'OUT019'], dtype=object)

# %%
data.Outlet_Establishment_Year.unique()
# Out:
# array([1999, 2009, 1998, 1987, 1985, 2002, 2007, 1997, 2004], dtype=int64)

# %%
data.Outlet_Size.unique()
# Out:
# array(['Medium', nan, 'High', 'Small'], dtype=object)

# %%
data.Outlet_Location_Type.unique()
# Out:
# array(['Tier 1', 'Tier 3', 'Tier 2'], dtype=object)

# %%
data.Item_Outlet_Sales.unique()
# Out:
# array([3735.138 ,  443.4228, 2097.27  , ..., 7182.6504, 3608.636 ,
#        2778.3834])

# %%
data.Outlet_Type.unique()
# Out:
# array(['Supermarket Type1', 'Supermarket Type2', 'Grocery Store',
#        'Supermarket Type3'], dtype=object)

# %%
a=data[["Outlet_Identifier","Outlet_Size"]]

# %%
a[a['Outlet_Size'].isna()].drop_duplicates()
# Out:
#   Outlet_Identifier Outlet_Size
# 3            OUT010         NaN
# 8            OUT045         NaN
# 9            OUT017         NaN

# %%
a.query('Outlet_Identifier=="OUT010"').drop_duplicates()
# Out:
#   Outlet_Identifier Outlet_Size
# 3            OUT010         NaN

# %%
a.query('Outlet_Identifier=="OUT045"').drop_duplicates()
# Out:
#   Outlet_Identifier Outlet_Size
# 8            OUT045         NaN

# %%
a.query('Outlet_Identifier=="OUT017"').drop_duplicates()
# Out:
#   Outlet_Identifier Outlet_Size
# 9            OUT017         NaN

# %%
data["Outlet_Size"].fillna('Unknown', inplace = True)

# %%
data["Outlet_Size"].isna().sum()
# Out:
# 0

# %%
data['Item_Fat_Content'].replace({'low fat':'Low Fat','LF':'Low Fat','reg':'Regular'}, inplace=True)

# %%
data['Item_Fat_Content'].unique()
# Out:
# array(['Low Fat', 'Regular'], dtype=object)

# %%
numerical_data = data.select_dtypes(include=np.number)

# %%
numerical_data
# Out:
#       Item_Weight  Item_Visibility  Item_MRP  Outlet_Establishment_Year  \
# 0           9.300         0.016047  249.8092                       1999
# 1           5.920         0.019278   48.2692                       2009
# 2          17.500         0.016760  141.6180                       1999
# 3          19.200         0.000000  182.0950                       1998
# 4           8.930         0.000000   53.8614                       1987
# ...           ...              ...       ...                        ...
# 8518        6.865         0.056783  214.5218                       1987
# 8519        8.380         0.046982  108.1570                       2002
# 8520       10.600         0.035186   85.1224                       2004
# 8521        7.210         0.145221  103.1332                       2009
# 8522       14.800         0.044878   75.4670                       1997
#
#       Item_Outlet_Sales
# 0             3735.1380
# 1              443.4228
# 2             2097.2700
# ...

# %%
categorical_data = data.select_dtypes(exclude=np.number)

# %%
categorical_data
# Out:
#      Item_Identifier Item_Fat_Content              Item_Type  \
# 0              FDA15          Low Fat                  Dairy
# 1              DRC01          Regular            Soft Drinks
# 2              FDN15          Low Fat                   Meat
# 3              FDX07          Regular  Fruits and Vegetables
# 4              NCD19          Low Fat              Household
# ...              ...              ...                    ...
# 8518           FDF22          Low Fat            Snack Foods
# 8519           FDS36          Regular           Baking Goods
# 8520           NCJ29          Low Fat     Health and Hygiene
# 8521           FDN46          Regular            Snack Foods
# 8522           DRG01          Low Fat            Soft Drinks
#
#      Outlet_Identifier Outlet_Size Outlet_Location_Type        Outlet_Type
# 0               OUT049      Medium               Tier 1  Supermarket Type1
# 1               OUT018      Medium               Tier 3  Supermarket Type2
# ...

# %%
#Performng standard scaling
from sklearn.preprocessing import StandardScaler
 
std_scale = StandardScaler()
df_std = std_scale.fit_transform(numerical_data)

# %%
categorical_data_processed = pd.get_dummies(categorical_data)

# %%
numerical_data_preprocessed = pd.DataFrame(df_std,columns = numerical_data.columns)

# %%
pre_processed_data = pd.concat([numerical_data_preprocessed,categorical_data_processed], axis = 1)

# %%
pre_processed_data
# Out:
#       Item_Weight  Item_Visibility  Item_MRP  Outlet_Establishment_Year  \
# 0       -0.828408        -0.970732  1.747454                   0.139541
# 1       -1.625364        -0.908111 -1.489023                   1.334103
# 2        1.105037        -0.956917  0.010040                   0.139541
# 3        1.505873        -1.281758  0.660050                   0.020085
# 4       -0.915649        -1.281758 -1.399220                  -1.293934
# ...           ...              ...       ...                        ...
# 8518    -1.402547        -0.181193  1.180783                  -1.293934
# 8519    -1.045331        -0.371154 -0.527301                   0.497909
# 8520    -0.521886        -0.599784 -0.897208                   0.736822
# 8521    -1.321200         1.532880 -0.607977                   1.334103
# 8522     0.468415        -0.411936 -1.052261                  -0.099372
#
#       Item_Outlet_Sales  Item_Identifier_DRA12  Item_Identifier_DRA24  \
# ...
